# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\locor\python1\Journals.csv')

# %%
df.head(10)
# Out:
#   Unnamed: 0                                              title  \
# 0       APEL                  Asian-Pacific Economic Literature
# 1     SAJoEH          South African Journal of Economic History
# 2         CE                            Computational Economics
# 3     MEPiTE  MOCT-MOST Economic Policy in Transitional Econ...
# 4       JoSE                         Journal of Socio-Economics
# 5      LabEc                                   Labour Economics
# 6        EDE              Environment and Development Economics
# 7      RoRPE              Review of Radical Political Economics
# 8        EoP                              Economics of Planning
# 9         Mt                                     Metroeconomica
#
#                 publisher society  price  pages  charpp  citations  \
# 0               Blackwell      no    123    440    3822         21
# 1  So Afr ec history assn      no     20    309    1782         22
# ...

# %%
df.describe() # 1.it will show statistical information about a DataFrame.
# Out:
#              price        pages       charpp    citations  foundingyear  \
# count   180.000000   180.000000   180.000000   180.000000    180.000000
# mean    417.722222   827.744444  3232.700000   647.055556   1966.905556
# std     385.834596   436.817402   819.358285  1182.373679     25.711484
# min      20.000000   167.000000  1782.000000    21.000000   1844.000000
# 25%     134.500000   548.750000  2715.000000    97.750000   1962.750000
# 50%     282.000000   693.000000  3010.000000   262.500000   1973.000000
# 75%     540.750000   974.250000  3476.750000   656.000000   1982.250000
# max    2120.000000  2632.000000  6859.000000  8999.000000   1996.000000
#
#               subs
# count   180.000000
# mean    196.866667
# std     204.528847
# min       2.000000
# 25%      52.000000
# 50%     122.500000
# 75%     268.250000
# max    1098.000000

# %%
df.drop_duplicates() # 2.it will remove duplicate rows from a DataFrame.
# Out:
#     Unnamed: 0                                              title  \
# 0         APEL                  Asian-Pacific Economic Literature
# 1       SAJoEH          South African Journal of Economic History
# 2           CE                            Computational Economics
# 3       MEPiTE  MOCT-MOST Economic Policy in Transitional Econ...
# 4         JoSE                         Journal of Socio-Economics
# ..         ...                                                ...
# 175       JoFi                                 Journal of Finance
# 176       QJoE                     Quarterly Journal of Economics
# 177    JoPolEc                       Journal of Political Economy
# 178      Ecnmt                                       Econometrica
# 179        AER                           American Economic Review
#
#                   publisher society  price  pages  charpp  citations  \
# 0                 Blackwell      no    123    440    3822         21
# ...

# %%
df.at[2,'price'] # 3.it will show value through index of rows and column name
# Out:
# 443

# %%
df.iat[2,4] # 4.it will show values through index of rows and index of column
# Out:
# 443

# %%
df.stack() # 5.it will stack columns of a DataFrame.
# Out:
# 0    Unnamed: 0                                   APEL
#      title           Asian-Pacific Economic Literature
#      publisher                               Blackwell
#      society                                        no
#      price                                         123
#                                    ...
# 179  charpp                                       3900
#      citations                                    8999
#      foundingyear                                 1911
#      subs                                         1098
#      field                                     General
# Length: 1980, dtype: object

# %%
df.unstack() # 6.it will unstack columns of a DataFrame.
# Out:
# Unnamed: 0  0         APEL
#             1       SAJoEH
#             2           CE
#             3       MEPiTE
#             4         JoSE
#                     ...
# field       175    Finance
#             176    General
#             177    General
#             178    General
#             179    General
# Length: 1980, dtype: object

# %%
df.dropna() # 7.it will drop rows or columns with missing values from a DataFrame.
# Out:
#     Unnamed: 0                                              title  \
# 0         APEL                  Asian-Pacific Economic Literature
# 1       SAJoEH          South African Journal of Economic History
# 2           CE                            Computational Economics
# 3       MEPiTE  MOCT-MOST Economic Policy in Transitional Econ...
# 4         JoSE                         Journal of Socio-Economics
# ..         ...                                                ...
# 175       JoFi                                 Journal of Finance
# 176       QJoE                     Quarterly Journal of Economics
# 177    JoPolEc                       Journal of Political Economy
# 178      Ecnmt                                       Econometrica
# 179        AER                           American Economic Review
#
#                   publisher society  price  pages  charpp  citations  \
# 0                 Blackwell      no    123    440    3822         21
# ...

# %%
df.value_counts() # 8.it will count the number of occurrences of each unique value in a Series.
# Out:
# Unnamed: 0  title                                    publisher  society  price  pages  charpp  citations  foundingyear  subs  field
# AE          Applied Economics                        Routledge  no       2120   1683   5445    578        1958          146   General                    1
# JoM         Journal of Macroeconomics                LSU Press  no       85     856    2562    137        1979          183   Macroeconomics             1
# JoMS        Journal of Management Studies            Blackwell  no       686    850    3456    654        1964          222   Management Science         1
# JoMathEc    Journal of Mathematical Economics        Elsevier   no       1147   1340   2940    418        1974          79    Theory                     1
# JoMonEc     Journal of Monetary Economics            Elsevier   no       1010   1346   3174    1860       1975          186   Macroeconomics             1
# ...

# %%
df.mean() # 9.it will calculate mean of int values
# Out:
# C:\Users\locor\AppData\Local\Temp\ipykernel_1000\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# price            417.722222
# pages            827.744444
# charpp          3232.700000
# citations        647.055556
# foundingyear    1966.905556
# subs             196.866667
# dtype: float64

# %%
df.median() # 10.it will calculate median of int values
# Out:
# C:\Users\locor\AppData\Local\Temp\ipykernel_1000\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# price            282.0
# pages            693.0
# charpp          3010.0
# citations        262.5
# foundingyear    1973.0
# subs             122.5
# dtype: float64

# %%
df.min() # 11.it will calculate min value of int column
# Out:
# Unnamed: 0                          AE
# title           Agricultural Economics
# publisher                    ANU Press
# society                             no
# price                               20
# pages                              167
# charpp                            1782
# citations                           21
# foundingyear                      1844
# subs                                 2
# field           Agricultural Economics
# dtype: object

# %%
df.max() # 11.it calculate max value of int column
# Out:
# Unnamed: 0                      WD
# title            World Development
# publisher                    Wiley
# society                        yes
# price                         2120
# pages                         2632
# charpp                        6859
# citations                     8999
# foundingyear                  1996
# subs                          1098
# field           Urban and Regional
# dtype: object

# %%
df.sum() # 12.it will calculate sum of int coulmn
# Out:
# Unnamed: 0      APELSAJoEHCEMEPiTEJoSELabEcEDERoRPEEoPMtJoCPRE...
# title           Asian-Pacific Economic LiteratureSouth African...
# publisher       BlackwellSo Afr ec history assnKluwerKluwerEls...
# society         nonononononononononononononononononononononono...
# price                                                       75190
# pages                                                      148994
# charpp                                                     581886
# citations                                                  116470
# foundingyear                                               354043
# subs                                                        35436
# field           GeneralEconomic HistorySpecializedArea Studies...
# dtype: object

# %%
df.cumsum() # 13.it will calculate cumulative sum of values of int column
# Out:
#                                             Unnamed: 0  \
# 0                                                 APEL
# 1                                           APELSAJoEH
# 2                                         APELSAJoEHCE
# 3                                   APELSAJoEHCEMEPiTE
# 4                               APELSAJoEHCEMEPiTEJoSE
# ..                                                 ...
# 175  APELSAJoEHCEMEPiTEJoSELabEcEDERoRPEEoPMtJoCPRE...
# 176  APELSAJoEHCEMEPiTEJoSELabEcEDERoRPEEoPMtJoCPRE...
# 177  APELSAJoEHCEMEPiTEJoSELabEcEDERoRPEEoPMtJoCPRE...
# 178  APELSAJoEHCEMEPiTEJoSELabEcEDERoRPEEoPMtJoCPRE...
# 179  APELSAJoEHCEMEPiTEJoSELabEcEDERoRPEEoPMtJoCPRE...
#
#                                                  title  \
# 0                    Asian-Pacific Economic Literature
# 1    Asian-Pacific Economic LiteratureSouth African...
# 2    Asian-Pacific Economic LiteratureSouth African...
# 3    Asian-Pacific Economic LiteratureSouth African...
# ...

# %%
df['price'].cov(df['pages']) # 14.it will calculate covariance between columns
# Out:
# 83211.93420235878

# %%
df['price'].corr(df['pages']) # 15.it will calculate correlation between columns
# Out:
# 0.4937243181529131

# %%
df['price'].diff() # 16.it will calculate the diffrence between consecutive values of column
# Out:
# 0        NaN
# 1     -103.0
# 2      423.0
# 3     -167.0
# 4       19.0
#        ...
# 175    -84.0
# 176    -78.0
# 177     11.0
# 178     19.0
# 179   -131.0
# Name: price, Length: 180, dtype: float64

# %%
df['pages'].rank(ascending=False) # 17.it will assign ranks to the values
# Out:
# 0      160.5
# 1      175.0
# 2      130.5
# 3      140.0
# 4       70.0
#        ...
# 175      2.0
# 176     20.0
# 177     13.0
# 178     19.0
# 179      9.0
# Name: pages, Length: 180, dtype: float64

# %%
df.sort_values(['price', 'pages'])[['price', 'pages']] # 18.it will sort the DataFrame by columns
# Out:
#      price  pages
# 1       20    309
# 115     36    910
# 139     45    530
# 162     45    850
# 101     45   1003
# ..     ...    ...
# 159   1450   1145
# 150   1492   1540
# 130   1539   1911
# 169   1893   1527
# 127   2120   1683
#
# [180 rows x 2 columns]

# %%
df1=pd.read_csv(r'C:\Users\locor\python1\student_marks.csv')

# %%
df1.head()
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
pd.concat([df,df1],ignore_index=True,axis=1) # 19.it will concatenate two or more DataFrames along a specified axis.
# Out:
#           0                                                  1   \
# 0       APEL                  Asian-Pacific Economic Literature
# 1     SAJoEH          South African Journal of Economic History
# 2         CE                            Computational Economics
# 3     MEPiTE  MOCT-MOST Economic Policy in Transitional Econ...
# 4       JoSE                         Journal of Socio-Economics
# ..       ...                                                ...
# 175     JoFi                                 Journal of Finance
# 176     QJoE                     Quarterly Journal of Economics
# 177  JoPolEc                       Journal of Political Economy
# 178    Ecnmt                                       Econometrica
# 179      AER                           American Economic Review
#
#                          2    3    4     5     6     7     8     9   ...   12  \
# 0                 Blackwell   no  123   440  3822    21  1986    14  ...    M
# ...

# %%
df.groupby('charpp')['pages'].mean() # 20.it will group data by one or more columns.
# Out:
# charpp
# 1782     309.0
# 1820     792.0
# 2072     607.0
# 2160     907.0
# 2178    1675.0
#          ...
# 5600     733.0
# 5610     774.0
# 5664    1260.0
# 6360     510.0
# 6859     568.0
# Name: pages, Length: 142, dtype: float64
